# %% [markdown]
# # Project: Car Prediction Using Machinea Learning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Car_Analyst.csv')
df.head(5)
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
df.head(100)
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 95                 Maruti Suzuki A Star Lxi     Maruti  2011       1,89,500
# 96                          Toyota Etios GD     Toyota  2013       3,50,000
# 97              Ford Figo Diesel EXI Option       Ford  2012       2,10,000
# 98  Maruti Suzuki Swift Dzire VXi 1.2 BS IV     Maruti  2014       3,90,000
# 99                 Chevrolet Beat LT Diesel  Chevrolet  2012       1,35,000
#
#     kms_driven fuel_type
# 0   45,000 kms    Petrol
# ...

# %% [markdown]
# ##### df's columns is 892, and 6 rows

# %%
df.shape
# Out:
# (892, 6)

# %%
df.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
df.info(verbose=True);
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
list(df['name'].unique())
# Out:
# ['Hyundai Santro Xing XO eRLX Euro III',
#  'Mahindra Jeep CL550 MDI',
#  'Maruti Suzuki Alto 800 Vxi',
#  'Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#  'Ford EcoSport Titanium 1.5L TDCi',
#  'Ford Figo',
#  'Hyundai Eon',
#  'Ford EcoSport Ambiente 1.5L TDCi',
#  'Maruti Suzuki Alto K10 VXi AMT',
#  'Skoda Fabia Classic 1.2 MPI',
#  'Maruti Suzuki Stingray VXi',
#  'Hyundai Elite i20 Magna 1.2',
#  'Mahindra Scorpio SLE BS IV',
#  'Audi A8',
#  'Audi Q7',
#  'Mahindra Scorpio S10',
#  'Maruti Suzuki Alto 800',
#  'Hyundai i20 Sportz 1.2',
#  'Maruti Suzuki Alto 800 Lx',
#  'Maruti Suzuki Vitara Brezza ZDi',
#  'Maruti Suzuki Alto LX',
#  'Mahindra Bolero DI',
#  'Maruti Suzuki Swift Dzire ZDi',
#  'Mahindra Scorpio S10 4WD',
#  'Maruti Suzuki Swift Vdi BSIII',
#  'Maruti Suzuki Wagon R VXi BS III',
#  'Maruti Suzuki Wagon R VXi Minor',
#  'Toyota Innova 2.0 G 8 STR BS IV',
#  'Renault Lodgy 85 PS RXL',
#  'Skoda Yeti Ambition 2.0 TDI CR 4x2',
#  'Maruti Suzuki Baleno Delta 1.2',
# ...

# %%
list(df['company'].unique())
# Out:
# ['Hyundai',
#  'Mahindra',
#  'Maruti',
#  'Ford',
#  'Skoda',
#  'Audi',
#  'Toyota',
#  'Renault',
#  'Honda',
#  'Datsun',
#  'Mitsubishi',
#  'Tata',
#  'Volkswagen',
#  'I',
#  'Chevrolet',
#  'Mini',
#  'BMW',
#  'Nissan',
#  'Hindustan',
#  'Fiat',
#  'Commercial',
#  'MARUTI',
#  'Force',
#  'Mercedes',
#  'Land',
#  'Yamaha',
#  'selling',
#  'URJENT',
#  'Swift',
#  'Used',
#  'Jaguar',
#  'Jeep',
#  'tata',
#  'Sale',
#  'very',
#  'Volvo',
#  'i',
#  '2012',
#  'Well',
#  'all',
#  '7',
#  '9',
#  'scratch',
#  'urgent',
#  'sell',
#  'TATA',
#  'Any',
#  'Tara']

# %%
df.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
list(df['Price'].unique())
# Out:
# ['80,000',
#  '4,25,000',
#  'Ask For Price',
#  '3,25,000',
#  '5,75,000',
#  '1,75,000',
#  '1,90,000',
#  '8,30,000',
#  '2,50,000',
#  '1,82,000',
#  '3,15,000',
#  '4,15,000',
#  '3,20,000',
#  '10,00,000',
#  '5,00,000',
#  '3,50,000',
#  '1,60,000',
#  '3,10,000',
#  '75,000',
#  '1,00,000',
#  '2,90,000',
#  '95,000',
#  '1,80,000',
#  '3,85,000',
#  '1,05,000',
#  '6,50,000',
#  '6,89,999',
#  '4,48,000',
#  '5,49,000',
#  '5,01,000',
#  '4,89,999',
#  '2,80,000',
#  '3,49,999',
#  '2,84,999',
#  '3,45,000',
#  '4,99,999',
#  '2,35,000',
#  '2,49,999',
#  '14,75,000',
#  '3,95,000',
#  '2,20,000',
#  '1,70,000',
#  '85,000',
#  '2,00,000',
#  '5,70,000',
#  '1,10,000',
#  '4,48,999',
#  '18,91,111',
#  '1,59,500',
#  '3,44,999',
#  '4,49,999',
#  '8,65,000',
#  '6,99,000',
#  '3,75,000',
#  '2,24,999',
#  '12,00,000',
#  '1,95,000',
#  '3,51,000',
#  '2,40,000',
#  '90,000',
#  '1,55,000',
#  '6,00,000',
#  '1,89,500',
#  '2,10,000',
#  '3,90,000',
#  '1,35,000',
# ...

# %%
list(df['kms_driven'].unique())
# Out:
# ['45,000 kms',
#  '40 kms',
#  '22,000 kms',
#  '28,000 kms',
#  '36,000 kms',
#  '59,000 kms',
#  '41,000 kms',
#  '25,000 kms',
#  '24,530 kms',
#  '60,000 kms',
#  '30,000 kms',
#  '32,000 kms',
#  '48,660 kms',
#  '4,000 kms',
#  '16,934 kms',
#  '43,000 kms',
#  '35,550 kms',
#  '39,522 kms',
#  '39,000 kms',
#  '55,000 kms',
#  '72,000 kms',
#  '15,975 kms',
#  '70,000 kms',
#  '23,452 kms',
#  '35,522 kms',
#  '48,508 kms',
#  '15,487 kms',
#  '82,000 kms',
#  '20,000 kms',
#  '68,000 kms',
#  '38,000 kms',
#  '27,000 kms',
#  '33,000 kms',
#  '46,000 kms',
#  '16,000 kms',
#  '47,000 kms',
#  '35,000 kms',
#  '30,874 kms',
#  '15,000 kms',
#  '29,685 kms',
#  '1,30,000 kms',
#  '19,000 kms',
#  nan,
#  '54,000 kms',
#  '13,000 kms',
#  '38,200 kms',
#  '50,000 kms',
#  '13,500 kms',
#  '3,600 kms',
#  '45,863 kms',
#  '60,500 kms',
#  '12,500 kms',
#  '18,000 kms',
#  '13,349 kms',
#  '29,000 kms',
#  '44,000 kms',
#  '42,000 kms',
#  '14,000 kms',
#  '49,000 kms',
# ...

# %%
list(df['year'].unique())
# Out:
# ['2007',
#  '2006',
#  '2018',
#  '2014',
#  '2015',
#  '2012',
#  '2013',
#  '2016',
#  '2010',
#  '2017',
#  '2008',
#  '2011',
#  '2019',
#  '2009',
#  '2005',
#  '2000',
#  '...',
#  '150k',
#  'TOUR',
#  '2003',
#  'r 15',
#  '2004',
#  'Zest',
#  '/-Rs',
#  'sale',
#  '1995',
#  'ara)',
#  '2002',
#  'SELL',
#  '2001',
#  'tion',
#  'odel',
#  '2 bs',
#  'arry',
#  'Eon',
#  'o...',
#  'ture',
#  'emi',
#  'car',
#  'able',
#  'no.',
#  'd...',
#  'SALE',
#  'digo',
#  'sell',
#  'd Ex',
#  'n...',
#  'e...',
#  'D...',
#  ', Ac',
#  'go .',
#  'k...',
#  'o c4',
#  'zire',
#  'cent',
#  'Sumo',
#  'cab',
#  't xe',
#  'EV2',
#  'r...',
#  'zest']

# %%
list(df['fuel_type'].unique())
# Out:
# ['Petrol', 'Diesel', nan, 'LPG']

# %%
df.isna().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
df.duplicated().any()
# Out:
# True

# %% [markdown]
# ## Quality of dataset
# 1. We select 3 element for name car.
# 2. check the null value and cleanning it
# 3. check duplicate and drop it
# 4. year column have the object value like {'r 15', 'Zest', 'ara)', and another}
# 5. year is object change it to integer
# 6. pirce column has 'Ask For Price' and ,
# 7. price is object change it to integer
# 8. kms_driven column has 'Petrol', kms and ,
# 9. kms_driven split it take only integer and covet to integer
# 10. 'fuel_type' has nan value cleaning it.

# %% [markdown]
# # Cleaning Data

# %%
# df_c = df.copy()

# %%
df
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %% [markdown]
# year column have the object value like {'r 15', 'Zest', 'ara)', and another}
# we need only year number not many noise letter or text

# %%
df = df[df['year'].str.isnumeric()]

# %%
df['year'].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '2003', '2004', '1995', '2002', '2001'], dtype=object)

# %%
df['year'] = df['year'].astype(int)
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_45896\1483339248.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['year'].astype(int)

# %% [markdown]
# Pirce column has 'Ask For Price' and ,
# price is object change it to integer

# %%
df = df[df['Price']!='Ask For Price']

# %%
df['Price'].head()
# Out:
# 0      80,000
# 1    4,25,000
# 3    3,25,000
# 4    5,75,000
# 6    1,75,000
# Name: Price, dtype: object

# %%
df['Price'] = df['Price'].str.replace(',','').astype(int)

# %% [markdown]
# kms_driven column has 'Petrol', kms and ,
# kms_driven split it take only integer and covet to integer

# %%
df['kms_driven'] = df['kms_driven'].str.split().str.get(0).str.replace(',','')

# %%
df['kms_driven']
# Out:
# 0       45000
# 1          40
# 3       28000
# 4       36000
# 6       41000
#         ...
# 886    132000
# 888     27000
# 889     40000
# 890    Petrol
# 891    Petrol
# Name: kms_driven, Length: 819, dtype: object

# %%
#df['kms_driven'] = df['kms_driven'].str.isnumeric()

# %%
df = df[df['kms_driven'].str.isnumeric()]

# %%
df['kms_driven'] = df['kms_driven'].astype(int)

# %%
df['kms_driven']
# Out:
# 0       45000
# 1          40
# 3       28000
# 4       36000
# 6       41000
#         ...
# 883     50000
# 885     30000
# 886    132000
# 888     27000
# 889     40000
# Name: kms_driven, Length: 817, dtype: int32

# %% [markdown]
# check the null value and cleanning it

# %%
df = df[~df['fuel_type'].isna()]
#df.dropna()
#df.isna().sum()

# %% [markdown]
# check duplicate and drop it

# %%
df.duplicated().any()
# Out:
# True

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 724 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        724 non-null    object
#  1   company     724 non-null    object
#  2   year        724 non-null    int32
#  3   Price       724 non-null    int32
#  4   kms_driven  724 non-null    int32
#  5   fuel_type   724 non-null    object
# dtypes: int32(3), object(3)
# memory usage: 31.1+ KB

# %% [markdown]
# Company does not need any cleaning now. Changing car names. Keeping only the first three words

# %%
df['name'] = df['name'].str.split().str.slice(start=0,stop=3).str.join(' ')

# %%
df.head()
# Out:
#                      name   company  year   Price  kms_driven fuel_type
# 0     Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1     Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3       Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4  Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6               Ford Figo      Ford  2012  175000       41000    Diesel

# %% [markdown]
# Resetting the index of the final cleaned data to be correct

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# Cleaned Data

# %%
df.head()
# Out:
#                      name   company  year   Price  kms_driven fuel_type
# 0     Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1     Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2       Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 3  Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 4               Ford Figo      Ford  2012  175000       41000    Diesel

# %%
df.shape
# Out:
# (724, 6)

# %%
df.describe()
# Out:
#               year         Price     kms_driven
# count   724.000000  7.240000e+02     724.000000
# mean   2012.321823  4.032451e+05   46791.342541
# std       4.122940  4.802936e+05   34575.416435
# min    1995.000000  3.000000e+04       0.000000
# 25%    2010.000000  1.650000e+05   27000.000000
# 50%    2013.000000  2.900000e+05   42000.000000
# 75%    2015.000000  4.899990e+05   59000.000000
# max    2019.000000  8.500003e+06  400000.000000

# %%
# outlier

# %%
df[df['Price']>6e6]
# Out:
#                    name   company  year    Price  kms_driven fuel_type
# 447  Mahindra XUV500 W6  Mahindra  2014  8500003       45000    Diesel

# %%
df['Price'].min()
# Out:
# 30000

# %%
df = df[df['Price']<6000000]

# %%
df.shape
# Out:
# (723, 6)

# %%
df.to_csv('Cleaned_Car_data.csv')

# %%
df
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 4                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 719      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 720          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 721    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 722            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 723      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [723 rows x 6 columns]

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
from pandas.plotting import scatter_matrix

# %%
pd.plotting.scatter_matrix(df);

# %%
sns.pairplot(data=df, diag_kind="kde", palette="husl");
# Out:
# C:\Users\MSI\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\MSI\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\MSI\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\MSI\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# C:\Users\MSI\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# ...

# %% [markdown]
# #### histogram for prices to see the ditribution data

# %%
sns.kdeplot(df.Price, shade = True);
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_45896\2128847770.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.Price, shade = True);

# %%
sns.distplot(df.Price, kde_kws={"lw": 5}, hist_kws={'alpha': 0.5});
plt.show()
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_45896\754670443.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Price, kde_kws={"lw": 5}, hist_kws={'alpha': 0.5});

# %%
sns.displot(df.Price,kde_kws = {'lw':5}, kde = False);

# %% [markdown]
# ### Check all factor affecting the price

# %% [markdown]
# Checking relationship of Company with Price

# %%
#plt.subplot(figsize=(15,7))
plt.figure(figsize=(10,7))
ax = sns.boxplot(x='company', y='Price', data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 40 , ha='right');
plt.show();
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_45896\1986381327.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation = 40 , ha='right');

# %% [markdown]
# Checking relationship of Year with Price

# %%
plt.figure(figsize=(15,7))
ax = sns.swarmplot(x='year', y='Price', data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 40, ha='right')
plt.show()
# Out:
# C:\Users\MSI\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\MSI\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 15.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\MSI\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 28.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\MSI\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 23.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# Checking relationship of kms_driven with Price

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(x='kms_driven', y='Price', data=df)
plt.show()

# %% [markdown]
# Checking relationship of Fuel Type with Price

# %%
plt.figure(figsize=(14,7))
sns.boxplot(x='fuel_type', y='Price', data=df, color='red')
plt.show()

# %% [markdown]
# # Model

# %%
df.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %% [markdown]
# Extract Training Data

# %%
y = df.drop(columns=['name','company', 'year','kms_driven', 'fuel_type'])
x = df[['name','company', 'year','kms_driven', 'fuel_type']]

# %%
print(x.shape)
print(y.shape)
# Out:
# (723, 5)
# (723, 1)

# %% [markdown]
# Extract for train(80%) and test(20%)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %% [markdown]
# create a OneHotEncoder object, One-hot encoding converts categorical data into a numerical format by creating binary columns for each category

# %%
ohe = OneHotEncoder()
#ohe.fit_transform()
ohe.fit(x[['name','company', 'fuel_type']])
# Out:
# OneHotEncoder()

# %% [markdown]
# Creating a column transformer to transform categorical columns

# %%
# column_tra = make_column_transformer((OneHotEncoder(handle_unknown='ignore'),['name','company', 'fuel_type']))

# %%
column_tra = make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company', 'fuel_type']))

# %% [markdown]
# Create model linear class

# %%
model = LinearRegression()

# %% [markdown]
# Make a pipeline

# %%
pipe = make_pipeline(column_tra,model)

# %% [markdown]
# Apply the training and test set in model

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#        'Chevrolet Beat LS...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
# ...

# %%
y_pred = pipe.predict(x_test) #predict

# %%
r2_score(y_test,y_pred)
# Out:
# 0.47041967502491

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_tra,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 893

# %%
scores[893]
# Out:
# 0.914487449067884

# %%
import pickle

# %%
# pickle.dump(df, open('df.pkl','wb'))

# %%
pickle.dump(pipe,open('LinearRegressionModel_Car_price_prediction.pkl','wb'))

# %%
pickle.dump(x_test,open('x_test_set.pkl','wb'))

# %%
pickle.load(open('LinearRegressionModel_Car_price_prediction.pkl','rb'))
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#        'Chevrolet Beat LS...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
# ...

# %%
pickle.dump(df,open('data_car_clean.pkl', 'wb'))

# %%
pipe.predict(pd.DataFrame(columns=['name', 'company', 'year', 'kms_driven', 'fuel_type']
                          ,data=np.array(['Maruti Suzuki Swift','Maruti',2019,100,'Petrol']).reshape(1,5)))
# Out:
# array([[265533.55290914]])

# %%
df.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
df['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'LPG'], dtype=object)

# %% [markdown]
# # Deployment in Streamlit

# %% [markdown]
# ![image.png](attachment:image.png)
